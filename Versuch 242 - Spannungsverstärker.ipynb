# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

rU=0.04 #relativer Fehler der Spannungswerte
def prop(x,m):
    return m*x
def linear(x,m,c):
    return m*x+c

# %%
U1_1a1=np.array([250,175,100,50,0,-75,-150,-250])
UA_1a1=np.array([-4.01,-2.82,-1.6,-0.781,0.035,1.2,2.46,4.12])
RG_1a1=48.7
V_1a1=UA_1a1/U1_1a1
dV_1a1=V_1a1*rU*np.sqrt(2)
plt.figure(1,(8,8))
plt.plot(U1_1a1,UA_1a1,'bo')

U1_1a2=np.array([-150,-110,-75,-30,0,50,100,150])
UA_1a2=np.array([13.8,10.2,6.8,2.79,0.123,-4.52,-9.2,-13])
RG_1a2=274
V_1a2=UA_1a2/U1_1a2
dV_1a2=V_1a2*rU*np.sqrt(2)
plt.plot(U1_1a2,UA_1a2,'ro')

U1_1b=np.array([1000,800,600,400,200,500])/10
UA_1b1=np.array([9.2,7.4,5.6,3.8,2.0,4.4])
RG_1b1=274
V_1b1=UA_1b1/U1_1b
dV_1b1=V_1b1*rU*np.sqrt(2)
plt.figure(2,(8,8))
plt.plot(U1_1b,UA_1b1,'bo')

UA_1b2=np.array([22.2,17.6,13.4,8.8,4.6,10.4])
RG_1b2=680
V_1b2=UA_1b2/U1_1b
dV_1b2=V_1b2*rU*np.sqrt(2)
plt.plot(U1_1b,UA_1b2,'ro')
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':

# %%
f=np.array([0.1,0.3,0.6,1,3,6,10,30,60,100,300])
UA_2a1=np.array([6.88,6.88,6.88,6.64,4.88,3.28,2.16,0.8,0.44,0.22,0.08])
U1_2a1=U1_2a2=0.3/10
RG_2a1=680
V_2a1=UA_2a1/U1_2a1
dV_2a1=V_2a1*rU*np.sqrt(2)
plt.figure(3,(12,12))
plt.xscale('log')
plt.yscale('log')
plt.errorbar(f,V_2a1,yerr=dV_2a1, fmt='bo')

UA_2a2=np.array([2.74,2.76,2.74,2.74,2.56,2.2,1.66,0.72,0.35,0.22,0.07])
RG_2a2=274
V_2a2=UA_2a2/U1_2a2
dV_2a2=V_2a2*rU*np.sqrt(2)
plt.errorbar(f,V_2a2,yerr=dV_2a2,fmt='ro')

UA_2a3=np.array([1.66,1.66,1.66,1.66,1.68,1.66,1.66,1.36,0.92,0.62,0.23])
U1_2a3=U1_2b=U1_2c=1/10
RG_2a3=RG_2b=RG_2c=48.7
V_2a3=UA_2a3/U1_2a3
dV_2a3=V_2a3*rU*np.sqrt(2)
plt.errorbar(f,V_2a3,yerr=dV_2a3,fmt='go')

UA_2b=np.array([1.66,1.66,1.66,1.62,1.5,1.2,0.9,0.34,0.18,0.1,0.04])
V_2b=UA_2b/U1_2b
dV_2b=V_2b*rU*np.sqrt(2)
plt.errorbar(f,V_2b,color="magenta", yerr=dV_2b)

f_2c=np.array([0.3,0.6,1,3,6,10,20])
UA_2c=np.array([0.52,0.88,1.2,1.6,1.72,1.68,1.56])
V_2c=UA_2c/U1_2c
dV_2c=V_2c*rU*np.sqrt(2)
plt.errorbar(f_2c,V_2c, color="black", yerr=dV_2c)
# Out:
# <ErrorbarContainer object of 3 artists>
